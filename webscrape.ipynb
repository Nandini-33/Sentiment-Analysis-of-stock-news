# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt

finviz_url = 'https://finviz.com/quote.ashx?t='
tickers = ['AMZN','GOOG','META','AAPL','MSFT','NVDA','TSLA','PG','MCD','NKE']
parsed_data = []
news_tables = {}
for ticker in tickers:
    url = finviz_url + ticker

    req = Request(url=url, headers={'user-agent': 'my-app'})
    response = urlopen(req)
    date=[]
    html = BeautifulSoup(response, features='html.parser')
    news_table = html.find(id='news-table')
    news_tables[ticker] = news_table
    data= news_table.findAll('tr')
    i=0
    for index,row in enumerate(data):
        if row.a:
            title = row.a.text
        parsed_data.append([ticker, title])
parsed_data
df = pd.DataFrame(parsed_data, columns=['ticker', 'title'])
df
# Out:
#     ticker                                              title
# 0     AMZN  Amazon expands PillPack pre-sorted med service...
# 1     AMZN  3 Reasons Amazon Could Be the Best Tech Perfor...
# 2     AMZN  Should You Hold on to AMZN Stock in 2H25 Despi...
# 3     AMZN  Constellation Energy stock soars on 20-year nu...
# 4     AMZN  Constellation Energy, Nuclear Stocks Jump on 2...
# ..     ...                                                ...
# 995    NKE  Retail stocks are still at risk with potential...
# 996    NKE  Urban Outfitters kicks off 'On Rotation' store...
# 997    NKE  Urban Outfitters and Nike Team Up to Court Gen...
# 998    NKE  NIKE, Inc. (NKE): Among Benjamin Graham Stocks...
# 999    NKE  Grupo SBF SA (BSP:SBFG3) Q1 2025 Earnings Call...
#
# [1000 rows x 2 columns]

# %%
df.to_csv('try.csv')
